# %%
import pandas as pd
import kaggle
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

kaggle_id = "piotrgrabo/breastcancerproteomes"

# %%
# Download data from Kaggle and save it to 'data' folder
kaggle.api.authenticate()
kaggle.api.dataset_download_files(kaggle_id, path="./", unzip=True)

# %%
df = pd.read_csv('77_cancer_proteomes_CPTAC_itraq.csv')

# %%
df.head()
# Out:
#   RefSeq_accession_number gene_symbol           gene_name  AO-A12D.01TCGA  \
# 0               NP_958782        PLEC   plectin isoform 1        1.096131
# 1               NP_958785         NaN  plectin isoform 1g        1.111370
# 2               NP_958786        PLEC  plectin isoform 1a        1.111370
# 3               NP_000436         NaN  plectin isoform 1c        1.107561
# 4               NP_958781         NaN  plectin isoform 1e        1.115180
#
#    C8-A131.01TCGA  AO-A12B.01TCGA  BH-A18Q.02TCGA  C8-A130.02TCGA  \
# 0        2.609943       -0.659828        0.195341       -0.494060
# 1        2.650422       -0.648742        0.215413       -0.503899
# 2        2.650422       -0.654285        0.215413       -0.500619
# 3        2.646374       -0.632113        0.205377       -0.510459
# 4        2.646374       -0.640428        0.215413       -0.503899
#
#    C8-A138.03TCGA  E2-A154.03TCGA  ...  AO-A12B.34TCGA  A2-A0SW.35TCGA  \
# ...

# %% [markdown]
# ### Minor data cleaning

# %%
# Drop non-numeric columns to keep only the expression data
df_numeric = df.drop(columns=['RefSeq_accession_number', 'gene_symbol', 'gene_name'])

# %% [markdown]
# ## Visualization

# %%
# Heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(df_numeric, cmap='viridis')
plt.title('Breast Cancer Proteome Heat Map')
plt.xlabel('Samples')
plt.ylabel('Genes')
plt.show()

# %%
# Boxplot (for a specific gene as an example, you can change the index to visualize other genes)
gene_index = 0  # Change this index to visualize other genes
sns.boxplot(x=df_numeric.loc[gene_index])
plt.title(f'Box Plot of Expression Levels for Gene {df.gene_symbol[gene_index]}')
plt.xlabel('Expression Level')
plt.show()
